# %% [markdown]
# <a href="https://colab.research.google.com/github/NE0BIT/colab-projects/blob/main/tictactoe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Important things that Alfred didnt tell you:**

# %% [markdown]
# **The ".lower()"**
#
# It can go in any variable, and it just transforms it into lowercase, it helps with compatibilty, check "Function filter of input" for a real use

# %% [markdown]
# **Print shenanigans**
#
# Inside a print, you can put leters that will modify something of how its printed:
#
# **print(r"")**; the letter r will make it so the printing is more acurate, check "The starting function" for a real use.
#
# **print(f"")**; the letter f will let you add variables into the text easy, for that, you have to put the variable in the text between {}, check the function to "Function to select dificulty" for a real use.

# %%
# @title Importing
# Import Libr
import random

# %%
# @title Global variables
# Define global variables
global username
username = ""
global a1, a2, a3, b1, b2, b3, c1, c2, c3
a1, a2, a3, b1, b2, b3, c1, c2, c3 = " ", " ", " ", " ", " ", " ", " ", " ", " "
global difficulty
difficulty = 0
global winner
winner = ""

# %%
# @title Funcion filter of input
# Function definiton
def get_valid_input(prompt, valid_options):
  # while True:                                           This calls a bucle that's infinte, you can only break it with the line "break"
  #   user_input = input(prompt).lower()                  This reads the input of the user that your going to select when you call the function
  #   if user_input in valid_options:                     This checks if the user input is one of the valid inputs (something else you have to specify when you call the function)
  #     return user_input                                 If everything is correct, it returns the input
  #   else:
  #     print("Entrada inválida. Inténtalo de nuevo.")    If not, it retuns a text that the input is not valid, and then tries again (because of the bucle)
  while True:
    user_input = input(prompt).lower()
    if user_input in valid_options:
      return user_input
    else:
      print("Entrada inválida. Inténtalo de nuevo.")

# %%
# @title Function to select dificulty
# Function definition and global variable calling
def dificulty_select():
  global username, difficulty
#   username = input("Introduze tu nombre usuario: ")                                 This reads the user input for the name and assings it into a variable
#   print(f'''¡Hola {username}!                                                       This prints a greeting and it lets the user select the dificulty

# Elije la dificultad:
# (1) Tirado
# (2) Posible''')
#   difficulty = int(get_valid_input("Introduce la dificultad (1-2): ", ["1", "2"]))  This assings the dificulty you choose to a variable transformed into an int, it does so with the preavious function
  username = input("Introduze tu nombre usuario: ")
  print(f'''¡Hola {username}!

Elije la dificultad:
(1) Tirado
(2) Posible''')
  difficulty = int(get_valid_input("Introduce la dificultad (1-2): ", ["1", "2"]))

# %%
# @title Function to print the move
# Function calling
def display_computer_move(row, col):
  #  move = row + col                                 This just adds the values you have to give it (the row and column) and fuses it together
  #  print(f"l'ordinador ha fet el moviment {move}")  And this prints the outcome of the "operation" with a nice text to make it apealing
   move = row + col
   print(f"l'ordinador ha fet el moviment {move}")

# %%
# @title Function to print the matrix
# Function definition and global variable calling
def print_matrix():
  global a1, a2, a3, b1, b2, b3, c1, c2, c3
  # game_matrix = [[a1, a2, a3], [b1, b2, b3], [c1, c2, c3]]  This defines the variable game matrix as a group with groups by the row
  # for row in game_matrix:                                   This itinerates (counts) the amount and values of the rows ther are (in this case 3)
  #   print("|".join(row))                                    And then, it prints a line "|" to separate the slots for the amount of rows (and what they have inside)
  # print()                                                   This just prints an empty space
  game_matrix = [[a1, a2, a3], [b1, b2, b3], [c1, c2, c3]]
  for row in game_matrix:
    print("|".join(row))
  print()

# %%
# @title Functon to check the looser
# Function definition and global variable calling
def check_free_space():
  global a1, a2, a3, b1, b2, b3, c1, c2, c3
  # if (a1 == " " or a2 == " " or a3 == " " or  This checks if the top row is filled with something or not
  #     b1 == " " or b2 == " " or b3 == " " or  Same with the second
  #     c1 == " " or c2 == " " or c3 == " "):   And same with the third, its an or, so the if will return true if there is something in any space
  #   return True                               Incase it fulfies (there is something) it will return true
  # else:
  #   return False                              This is the other case, where its has something
  if (a1 == " " or a2 == " " or a3 == " " or
      b1 == " " or b2 == " " or b3 == " " or
      c1 == " " or c2 == " " or c3 == " "):
    return True
  else:
    return False

# %%
# @title Function to check the winner
# Function definition and global variable calling
def check_win():
  global a1, a2, a3, b1, b2, b3, c1, c2, c3, winner
  # if (a1 == a2 == a3 != " ") or \                                               This lines checks if the line is completed with the same symbol, which would mean someone won
  #    (b1 == b2 == b3 != " ") or \
  #    (c1 == c2 == c3 != " ") or \
  #    (a1 == b1 == c1 != " ") or \
  #    (a2 == b2 == c2 != " ") or \
  #    (a3 == b3 == c3 != " ") or \
  #    (a1 == b2 == c3 != " ") or \
  #    (a3 == b2 == c1 != " "):
  #   winner = username if (a1 == "X" or b1 == "X" or c1 == "X") else "Ordinador" This changes the variable winner to the winner depending on the symbol that is filled, X for user and O for computer
  #   return winner                                                               This returns the other case
  # else:
  #   return None                                                                 This returns nothing if no one won (yet)
  if (a1 == a2 == a3 != " ") or \
     (b1 == b2 == b3 != " ") or \
     (c1 == c2 == c3 != " ") or \
     (a1 == b1 == c1 != " ") or \
     (a2 == b2 == c2 != " ") or \
     (a3 == b3 == c3 != " ") or \
     (a1 == b2 == c3 != " ") or \
     (a3 == b2 == c1 != " "):
    winner = username if (a1 == "X" or b1 == "X" or c1 == "X") else "Ordinador"
    return winner
  else:
    return None

# %%
# @title Function to register user moves
# Function definition and global variable calling
def user_move():
  global a1, a2, a3, b1, b2, b3, c1, c2, c3
  # while True:                                                                     This calls an infinite bucle that can only be broken with "break"
  #   row = get_valid_input("Introduce la fila (a, b, c): ", ["a", "b", "c"])       This registers the row that the player chose
  #   col = get_valid_input("Introduce la columna (1, 2, 3): ", ["1", "2", "3"])    The same with the column
  #   if row == "a" and col == "1" and a1 == " ":                                   This checks if the option the user chose is available
  #     a1 = "X"                                                                    If its indeed available, it registers the move
  #     break                                                                       And this breaks the bucle
  #   elif row == "a" and col == "2" and a2 == " ":                                 This is one of the many extra conditions to fulfill every slot
  #     a2 = "X"
  #     break
  while True:
    row = get_valid_input("Introduce la fila (a, b, c): ", ["a", "b", "c"])
    col = get_valid_input("Introduce la columna (1, 2, 3): ", ["1", "2", "3"])
    if row == "a" and col == "1" and a1 == " ":
      a1 = "X"
      break
    elif row == "a" and col == "2" and a2 == " ":
      a2 = "X"
      break
    elif row == "a" and col == "3" and a3 == " ":
      a3 = "X"
      break
    elif row == "b" and col == "1" and b1 == " ":
      b1 = "X"
      break
    elif row == "b" and col == "2" and b2 == " ":
      b2 = "X"
      break
    elif row == "b" and col == "3" and b3 == " ":
      b3 = "X"
      break
    elif row == "c" and col == "1" and c1 == " ":
      c1 = "X"
      break
    elif row == "c" and col == "2" and c2 == " ":
      c2 = "X"
      break
    elif row == "c" and col == "3" and c3 == " ":
      c3 = "X"
      break
    else:
      print("Movimiento inválido. Inténtalo de nuevo.")
    # else:                                                  This right here is an else, and it means that if none of the other conditions where met
    #   print("Movimiento inválido. Inténtalo de nuevo.")    This shows a message that the movements is invalid, because is the only explanation of something that can get past the initials if's

# %%
# @title Algorithm for "tirada" dificulty
# Function defenition and glibal variable calling
def computer_tirada(): #                              This function is the same of the user move, but changing the input from a human to random input
  global a1, a2, a3, b1, b2, b3, c1, c2, c3
    # while True:                                     Here, we just start and "infinite" bucle that we have to manually stop with "break"
    #   row = random.choice(["a", "b", "c"])          We call a library so it choses a random option between the tree rows
    #   col = random.choice(["1", "2", "3"])          The same with the columns
    #   if row == "a" and col == "1" and a1 == " ":   Here we check the random results, and also check if thats a free space
    #     a1 = "O"                                    If the conditional was true, then the computer fills that slot
    #     display_computer_move("a", "1")             And this line calls a function that was made preaviously so the program can understand easily what the computer made
    #     break                                       This breaks the said bucle
    #   elif row == "a" and col == "2" and a2 == " ": This is the next conditional, this will be replicated till we do all combinations
    #     a2 = "O"
    #     display_computer_move("a", "2")
    #     break
  while True:
    row = random.choice(["a", "b", "c"])
    col = random.choice(["1", "2", "3"])
    if row == "a" and col == "1" and a1 == " ":
      a1 = "O"
      display_computer_move("a", "1")
      break
    elif row == "a" and col == "2" and a2 == " ":
      a2 = "O"
      display_computer_move("a", "2")
      break
    elif row == "a" and col == "3" and a3 == " ":
      a3 = "O"
      display_computer_move("a", "3")
      break
    elif row == "b" and col == "1" and b1 == " ":
      b1 = "O"
      display_computer_move("b", "1")
      break
    elif row == "b" and col == "2" and b2 == " ":
      b2 = "O"
      display_computer_move("b", "2")
      break
    elif row == "b" and col == "3" and b3 == " ":
      b3 = "O"
      display_computer_move("b", "3")
      break
    elif row == "c" and col == "1" and c1 == " ":
      c1 = "O"
      display_computer_move("c", "1")
      break
    elif row == "c" and col == "2" and c2 == " ":
      c2 = "O"
      display_computer_move("c", "2")
      break
    elif row == "c" and col == "3" and c3 == " ":
      c3 = "O"
      display_computer_move("c", "3")
      break

# %%
# @title Algorithm for "posible" dificulty
# Function defenition and global variable calling
def computer_posible():
  global a1, a2, a3, b1, b2, b3, c1, c2, c3
  # Check for a free space with a preaviously created function
  if not check_free_space():
    return
  # Check for winning move, its done manually, detailed explanation
  # if (a1 == a2 == "O" and a3 == " ") or (b3 == c3 == "O" and a3 == " ") or (c1 == b2 == "O" and a3 == " "): Here we check for the specific cases where a specific move would make it win
  #   a3 = "O"                                                                                                If that is the case, then the specific slot will be filled with the winning move
  #   display_computer_move("a", "3")                                                                         This line helps the code know which move the computer made, so its easier to print after for easy understanding to the player
  # elif (a1 == a3 == "O" and a2 == " ") or (b2 == c2 == "O" and a2 == " "):                                  This is one of many other examples, in this case elif that allows another condition to the starting conditional (the IF)
  #   a2 = "O"
  #   display_computer_move("a", "2")
  if (a1 == a2 == "O" and a3 == " ") or (b3 == c3 == "O" and a3 == " ") or (c1 == b2 == "O" and a3 == " "):
    a3 = "O"
    display_computer_move("a", "3")
  elif (a1 == a3 == "O" and a2 == " ") or (b2 == c2 == "O" and a2 == " "):
    a2 = "O"
    display_computer_move("a", "2")
  elif (a2 == a3 == "O" and a1 == " ") or (c1 == b1 == "O" and a1 == " ") or (c2 == b2 == "O" and a1 == " "):
    a1 = "O"
    display_computer_move("a", "1")
  elif (b1 == b2 == "O" and b3 == " ") or (a3 == c3 == "O" and b3 == " "):
    b3 = "O"
    display_computer_move("b", "3")
  elif (b1 == b3 == "O" and b2 == " ") or (a2 == c2 == "O" and b2 == " "):
    b2 = "O"
    display_computer_move("b", "2")
  elif (b2 == b3 == "O" and b1 == " ") or (a1 == c1 == "O" and b1 == " "):
    b1 = "O"
    display_computer_move("b", "1")
  elif (c1 == c2 == "O" and c3 == " ") or (a1 == b1 == "O" and c3 == " ") or (b2 == a3 == "O" and c3 == " "):
    c3 = "O"
    display_computer_move("c", "3")
  elif (c1 == c3 == "O" and c2 == " ") or (a2 == b2 == "O" and c2 == " "):
    c2 = "O"
    display_computer_move("c", "2")
  elif (c2 == c3 == "O" and c1 == " ") or (a1 == b1 == "O" and c1 == " ") or (a3 == b2 == "O" and c1 == " "):
    c1 = "O"
    display_computer_move("c", "1")
  # Check for diagonal winning move, the same structure at the preavious one
  elif (a1 == b2 == "O" and c3 == " "):
    c3 = "O"
    display_computer_move("c", "3")
  elif (a3 == b2 == "O" and c1 == " "):
    c1 = "O"
    display_computer_move("c", "1")
  elif (c1 == b2 == "O" and a3 == " "):
    a3 = "O"
    display_computer_move("a", "3")
  elif (c3 == b2 == "O" and a1 == " "):
    a1 = "O"
    display_computer_move("a", "1")
  elif (a1 == c3 == "O" and b2 == " "):
    b2 = "O"
    display_computer_move("b", "2")
  elif (a3 == c1 == "O" and b2 == " "):
    b2 = "O"
    display_computer_move("b", "2")
  # Check for blocking move, in this case, it does the same but instead cheaking the posotions where the player would win and blocking them
  elif (a1 == a2 == "X" and a3 == " ") or (b3 == c3 == "X" and a3 == " ") or (c1 == b2 == "X" and a3 == " "):
    a3 = "O"
    display_computer_move("a", "3")
  elif (a1 == a3 == "X" and a2 == " ") or (b2 == c2 == "X" and a2 == " "):
    a2 = "O"
    display_computer_move("a", "2")
  elif (a2 == a3 == "X" and a1 == " ") or (c1 == b1 == "X" and a1 == " ") or (c2 == b2 == "X" and a1 == " "):
    a1 = "O"
    display_computer_move("a", "1")
  elif (b1 == b2 == "X" and b3 == " ") or (a3 == c3 == "X" and b3 == " "):
    b3 = "O"
    display_computer_move("b", "3")
  elif (b1 == b3 == "X" and b2 == " ") or (a2 == c2 == "X" and b2 == " "):
    b2 = "O"
    display_computer_move("b", "2")
  elif (b2 == b3 == "X" and b1 == " ") or (a1 == c1 == "X" and b1 == " "):
    b1 = "O"
    display_computer_move("b", "1")
  elif (c1 == c2 == "X" and c3 == " ") or (a1 == b1 == "X" and c3 == " ") or (b2 == a3 == "X" and c3 == " "):
    c3 = "O"
    display_computer_move("c", "3")
  elif (c1 == c3 == "X" and c2 == " ") or (a2 == b2 == "X" and c2 == " "):
    c2 = "O"
    display_computer_move("c", "2")
  elif (c2 == c3 == "X" and c1 == " ") or (a1 == b1 == "X" and c1 == " ") or (a3 == b2 == "X" and c1 == " "):
    c1 = "O"
    display_computer_move("c", "1")
  # Check for diagonal blocking move, again, same as the preavious
  elif (a1 == b2 == "X" and c3 == " "):
    c3 = "O"
    display_computer_move("c", "3")
  elif (a3 == b2 == "X" and c1 == " "):
    c1 = "O"
    display_computer_move("c", "1")
  elif (c1 == b2 == "X" and a3 == " "):
    a3 = "O"
    display_computer_move("a", "3")
  elif (c3 == b2 == "X" and a1 == " "):
    a1 = "O"
    display_computer_move("a", "1")
  # Choose center if available, this is in the case that there is no winning/lossing move, and then just getting the center (if posible) because its just a good play
  elif b2 == " ":
    b2 = "O"
    display_computer_move("b", "2")
  # Choose randomly, this is the last resort, it chooses a random slot if no center, no winning, or no blocking move is available
  else:
    while True:
      row = random.choice(["a", "b", "c"])
      col = random.choice(["1", "2", "3"])
      if row == "a" and col == "1" and a1 == " ":
        a1 = "O"
        display_computer_move("a", "1")
        break
      elif row == "a" and col == "2" and a2 == " ":
        a2 = "O"
        display_computer_move("a", "2")
        break
      elif row == "a" and col == "3" and a3 == " ":
        a3 = "O"
        display_computer_move("a", "3")
        break
      elif row == "b" and col == "1" and b1 == " ":
        b1 = "O"
        display_computer_move("b", "1")
        break
      elif row == "b" and col == "2" and b2 == " ":
        b2 = "O"
        display_computer_move("b", "2")
        break
      elif row == "b" and col == "3" and b3 == " ":
        b3 = "O"
        display_computer_move("b", "3")
        break
      elif row == "c" and col == "1" and c1 == " ":
        c1 = "O"
        display_computer_move("c", "1")
        break
      elif row == "c" and col == "2" and c2 == " ":
        c2 = "O"
        display_computer_move("c", "2")
        break
      elif row == "c" and col == "3" and c3 == " ":
        c3 = "O"
        display_computer_move("c", "3")
        break
# The order of the code is very important, because python does the first lines with highier priority, you have to order the priorities too

# %%
# @title Main game function (bucle)
# Function defenition and global variable calling
def start_game(start_player):
  global winner
  # A line of conditionals that start the game depending on the dificulty, and whoever you have chosen to move first, here is an example
  # if difficulty == 1 and start_player == "yo":  Checks for the dificulty and the first player
  #   while True:                                 The start of an infinite bucle, it will be broken with the "break" command
  #     print_matrix()                            Here it calls the function to print the matrix, which at this point is empty
  #     user_move()                               Here in case is the user turn, it calls to that function made preaviously for easy organization
  #     winner = check_win()                      Here it checks if someone wins, because after every turn it has to check
  #     if winner:                                A conditional that would trully be if winner != "", In this case is checking if winner has any value
  #       print_matrix()                          If it does, it prints the last matrix so you know how you lost/win
  #       print(f"¡El guanyador és {winner}!")    Prints a text saying who won
  #       break                                   And breaks the bucle, thus the code
  #     if not check_free_space() and not winner: Here it checks if there is no empty space with a function made preaviously, and there is no winner, which means a tie
  #       print("¡Empate!")                       Prints the text saying that there has been a tie
  #       break                                   Again, it breaks the bucle thus code
  #     computer_tirada()                         This is if the winner is equal to nothing, it will move to the next turn, in this case, the computer
  #     winner = check_win()                      Again, checks for the winner
  #     if winner:
  #       print_matrix()
  #       print(f"¡El guanyador és {winner}!")
  #       break
  #     if not check_free_space() and not winner:
  #       print("¡Empate!")
  #       break                                   After this line, after checking for a winner, the bucle starts again till there is an end

  if difficulty == 1 and start_player == "yo":
    while True:
      print_matrix()
      user_move()
      winner = check_win()
      if winner:
        print_matrix()
        print(f"¡El guanyador és {winner}!")
        break
      if not check_free_space() and not winner:
        print("¡Empate!")
        break
      computer_tirada()
      winner = check_win()
      if winner:
        print_matrix()
        print(f"¡El guanyador és {winner}!")
        break
      if not check_free_space() and not winner:
        print("¡Empate!")
        break
  elif difficulty == 1 and start_player == "tu":
    while True:
      print_matrix()
      computer_tirada()
      winner = check_win()
      if winner:
        print_matrix()
        print(f"¡El guanyador és {winner}!")
        break
      if not check_free_space() and not winner:
        print("¡Empate!")
        break
      print_matrix()
      user_move()
      winner = check_win()
      if winner:
        print_matrix()
        print(f"¡El guanyador és {winner}!")
        break
      if not check_free_space() and not winner:
        print("¡Empate!")
        break
  elif difficulty == 2 and start_player == "yo":
    while True:
      print_matrix()
      user_move()
      winner = check_win()
      if winner:
        print_matrix()
        print(f"¡El guanyador és {winner}!")
        break
      if not check_free_space() and not winner:
        print("¡Empate!")
        break
      print_matrix()
      computer_posible()
      winner = check_win()
      if winner:
        print_matrix()
        print(f"¡El guanyador és {winner}!")
        break
      if not check_free_space() and not winner:
        print("¡Empate!")
        break
  elif difficulty == 2 and start_player == "tu":
    while True:
      print_matrix()
      computer_posible()
      winner = check_win()
      if winner:
        print_matrix()
        print(f"¡El guanyador és {winner}!")
        break
      if not check_free_space() and not winner:
        print("¡Empate!")
        break
      print_matrix()
      user_move()
      winner = check_win()
      if winner:
        print_matrix()
        print(f"¡El guanyador és {winner}!")
        break
      if not check_free_space() and not winner:
        print("¡Empate!")
        break

# %%
# @title The starting function
#Function Definition and global variable calling
def mainpage():
  global username, difficulty
  # This is just the starting text so the game looks preatier
  print(r'''
 _   _      _             _
| | (_)    | |           | |
| |_ _  ___| |_ __ _  ___| |_ ___   ___
| __| |/ __| __/ _` |/ __| __/ _ \ / _ \
| |_| | (__| || (_| | (__| || (_) |  __/
 \__|_|\___|\__\__,_|\___|\__\___/ \___|

El fantastico juego de tres en raya
Ahora con IA (no es ia pero como si lo fuera)
''')
  #Here we call the functions that forms the main game
  dificulty_select()
  valid_starters = ["tu", "yo"]
  start_player = get_valid_input("¿Quién empieza? (tu/yo): ", valid_starters)
  start_game(start_player)

# %%
mainpage()
# Out:
#
#  _   _      _             _
# | | (_)    | |           | |
# | |_ _  ___| |_ __ _  ___| |_ ___   ___
# | __| |/ __| __/ _` |/ __| __/ _ \ / _ \
# | |_| | (__| || (_| | (__| || (_) |  __/
#  \__|_|\___|\__\__,_|\___|\__\___/ \___|
#
# El fantastico juego de tres en raya
# Ahora con IA (no es ia pero como si lo fuera)
#
# Introduze tu nombre usuario: Dokko
# ¡Hola Dokko!
#
# Elije la dificultad:
# (1) Tirado
# (2) Posible
# Introduce la dificultad (1-2): 2
# ¿Quién empieza? (tu/yo): tu
#  | |
#  | |
#  | |
#
# l'ordinador ha fet el moviment b2
#  | |
#  |O|
#  | |
#
# Introduce la fila (a, b, c): c
# Introduce la columna (1, 2, 3): 3
#  | |
#  |O|
#  | |X
#
# l'ordinador ha fet el moviment b3
#  | |
#  |O|O
#  | |X
#
# Introduce la fila (a, b, c): a
# Introduce la columna (1, 2, 3): 2
#  |X|
#  |O|O
#  | |X
#
# l'ordinador ha fet el moviment b1
#  |X|
# O|O|O
#  | |X
#
# ¡El guanyador és Ordinador!
